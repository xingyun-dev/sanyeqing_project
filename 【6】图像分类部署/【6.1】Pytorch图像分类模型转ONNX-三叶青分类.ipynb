# %% [markdown]
# # Pytorch图像分类模型转ONNX-三叶青分类
#
# 2024/5/1

# %% [markdown]
# ## 安装配置环境

# %%
# %pip install torch torchvision --extra-index-url https://download.pytorch.org/whl/cu113  #安装 Pytorch
# %pip install onnx -i https://pypi.tuna.tsinghua.edu.cn/simple  #安装 ONNX
# %pip install onnxruntime -i https://pypi.tuna.tsinghua.edu.cn/simple #安装推理引擎 ONNX Runtime
# %pip install numpy pandas matplotlib tqdm opencv-python pillow -i https://pypi.tuna.tsinghua.edu.cn/simple  #安装其它第三方工具包

# %% [markdown]
# ## 导入工具包

# %%
import torch
import torchvision
from torch import nn

# 有 GPU就用 GPU，没有就用 CPU
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print('device is', device)
# Out:
# device is cpu

# %% [markdown]
# # 从模型文件转化为权重文件

# %%
# 加载模型
model = torch.load(r"D:\model_bests_3.pth", map_location='cpu')
# 获取模型的权重
weights = model.state_dict()
#保存权重到文件中
torch.save(weights, 'model_bests_3.pth')

# %% [markdown]
# # GPU转为CPU（按需要进行）

# %%
import torch
import torchvision
from torch import nn
def get_mobilenet(device, model_name, num_classes=3):
        base_model_func = getattr(torchvision.models, model_name)   # 加载预训练的MobileNetV2模型
        base_model = base_model_func(pretrained=True)
        if model_name == "mobilenet_v2":
            num_features = base_model.classifier[-1].in_features
            classifier = nn.Sequential(    # 定义一个新的分类头
                nn.Linear(num_features, 256),
                nn.ReLU(),
                nn.Linear(256, num_classes)
            )
            base_model.classifier = classifier    # 替换原有的分类头
        else:
            num_features = base_model.features[-1].out_channels      # 获取最后一个卷积层的输出通道数量
            classifier = nn.Sequential(                # 定义一个新的分类头
                nn.Linear(num_features, 256),
                nn.ReLU(),
                nn.Linear(256, num_classes)
            )
            base_model.classifier = classifier  # 替换原有的分类头
        base_model = base_model.to(device)    # 将模型参数分配到指定设备
        for name, param in base_model.named_parameters():    # 冻结特征提取器的参数
            if 'classifier' not in name:  # 确保只冻结特征提取部分的参数
                param.requires_grad = False
        return base_model
def load_model_on_cpu(model_path, model_name):
    device = torch.device('cpu') # 创建模型
    model = get_mobilenet(device,model_name)
    state_dict = torch.load(model_path, map_location='cpu')  # 加载模型参数
    state_dict = {k.replace('module.', ''): v for k, v in state_dict.items()}   # 如果模型是在多GPU环境下训练的，模型参数的键会包含 'module.' 前缀，我们需要先去除这个前缀
    model.load_state_dict(state_dict)   # 加载参数到模型
    print(model)
    return model
# 使用方法
model_path = r"D:\SanYeQing_Project\wht_sanyeqing_image-Classification\【6】ONNX Runtime图像分类部署\model_bests_3.pth"
model = load_model_on_cpu(model_path,model_name="mobilenet_v3_large")
torch.save(model, 'model_cpu_3.pth')
# Out:
# MobileNetV3(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#     (1): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (2): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#           (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(64, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (3): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (4): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(72, 72, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=72, bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(72, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (5): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (6): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (7): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (8): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(80, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=200, bias=False)
#           (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(200, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (9): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(80, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(184, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (10): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(80, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(184, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (11): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#           (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(112, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (12): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(112, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (13): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(672, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (14): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (15): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (16): Conv2dNormActivation(
#       (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Linear(in_features=960, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=3, bias=True)
#   )
# )

# %% [markdown]
# ## 加载训练得到的三叶青图像分类Pytorch模型文件

# %%
INPUT_DICT = r"D:\SanYeQing_Project\wht_sanyeqing_image-Classification\model_zheng_path\model_cpu_11.pth"  # 模型文件
OUT_ONNX = 'model_cpu_11.onnx' # 导出的onnx模型文件
x = torch.randn(1, 3, 224, 224)  # 定义一个随机的输入张量，用于导出模型。
input_names = ["input"] # 输入张量的名字
out_names = ["output"] # 输出张量的名字

model =torch.load(INPUT_DICT,map_location=device) # 加载自己训练的模型
print(model)
# Out:
# MobileNetV3(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#     (1): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (2): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#           (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(64, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (3): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (4): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(72, 72, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=72, bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(72, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (5): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (6): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (7): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (8): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(80, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=200, bias=False)
#           (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(200, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (9): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(80, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(184, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (10): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(80, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(184, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (11): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#           (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(112, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (12): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(112, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (13): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(672, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (14): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (15): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (16): Conv2dNormActivation(
#       (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Linear(in_features=960, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=11, bias=True)
#   )
# )

# %% [markdown]
# ## 评估模式

# %%
model = model.eval().to(device)
print(device)
# Out:
# cpu

# %% [markdown]
# ## 输入Pytorch模型推理预测，获得n个类别的预测结果

# %%
# 当你有输入数据时
# x = x.to(device)  # 将输入数据移动到 CPU
output = model(x)
print(output.shape)
# Out:
# torch.Size([1, 11])

# %% [markdown]
# ## Pytorch模型转ONNX模型

# %%
with torch.no_grad():
    torch.onnx.export(
                model,  #要转换的模型
                x,  #模型的任意一组输入
                OUT_ONNX,  #导出的ONNX文件名
                opset_version=11, #ONNX的算子集版本
                input_names=input_names, #输入Tensor的名称
                output_names=out_names, #输入Tensor的名称
    )

# onnxsim是一个用于优化和简化ONNX模型的工具，可以减小模型文件的大小并加速推理过程。
print('please run: python -m onnxsim test.onnx test_sim.onnx\n')
# Out:
# please run: python -m onnxsim test.onnx test_sim.onnx

# %% [markdown]
# ## 验证onnx模型导出成功

# %%
import onnx

# 读取 ONNX 模型
onnx_model = onnx.load('model_cpu_97.18.onnx')
# 检查模型格式是否正确
onnx.checker.check_model(onnx_model)

print('ok,onnx模型载入成功')
# Out:
# ok,onnx模型载入成功

# %% [markdown]
# ## 以可读的形式打印计算图

# %%
print(onnx.helper.printable_graph(onnx_model.graph))
# Out:
# graph main_graph (
#   %input[FLOAT, 1x3x224x224]
# ) initializers (
#   %features.4.block.2.fc1.weight[FLOAT, 24x72x1x1]
#   %features.4.block.2.fc1.bias[FLOAT, 24]
#   %features.4.block.2.fc2.weight[FLOAT, 72x24x1x1]
#   %features.4.block.2.fc2.bias[FLOAT, 72]
#   %features.5.block.2.fc1.weight[FLOAT, 32x120x1x1]
#   %features.5.block.2.fc1.bias[FLOAT, 32]
#   %features.5.block.2.fc2.weight[FLOAT, 120x32x1x1]
#   %features.5.block.2.fc2.bias[FLOAT, 120]
#   %features.6.block.2.fc1.weight[FLOAT, 32x120x1x1]
#   %features.6.block.2.fc1.bias[FLOAT, 32]
#   %features.6.block.2.fc2.weight[FLOAT, 120x32x1x1]
#   %features.6.block.2.fc2.bias[FLOAT, 120]
#   %features.11.block.2.fc1.weight[FLOAT, 120x480x1x1]
#   %features.11.block.2.fc1.bias[FLOAT, 120]
#   %features.11.block.2.fc2.weight[FLOAT, 480x120x1x1]
#   %features.11.block.2.fc2.bias[FLOAT, 480]
#   %features.12.block.2.fc1.weight[FLOAT, 168x672x1x1]
#   %features.12.block.2.fc1.bias[FLOAT, 168]
#   %features.12.block.2.fc2.weight[FLOAT, 672x168x1x1]
#   %features.12.block.2.fc2.bias[FLOAT, 672]
#   %features.13.block.2.fc1.weight[FLOAT, 168x672x1x1]
#   %features.13.block.2.fc1.bias[FLOAT, 168]
#   %features.13.block.2.fc2.weight[FLOAT, 672x168x1x1]
#   %features.13.block.2.fc2.bias[FLOAT, 672]
#   %features.14.block.2.fc1.weight[FLOAT, 240x960x1x1]
#   %features.14.block.2.fc1.bias[FLOAT, 240]
#   %features.14.block.2.fc2.weight[FLOAT, 960x240x1x1]
#   %features.14.block.2.fc2.bias[FLOAT, 960]
#   %features.15.block.2.fc1.weight[FLOAT, 240x960x1x1]
#   %features.15.block.2.fc1.bias[FLOAT, 240]
#   %features.15.block.2.fc2.weight[FLOAT, 960x240x1x1]
#   %features.15.block.2.fc2.bias[FLOAT, 960]
#   %classifier.0.weight[FLOAT, 256x960]
#   %classifier.0.bias[FLOAT, 256]
#   %classifier.2.weight[FLOAT, 6x256]
#   %classifier.2.bias[FLOAT, 6]
#   %onnx::Conv_520[FLOAT, 16x3x3x3]
#   %onnx::Conv_521[FLOAT, 16]
#   %onnx::Conv_523[FLOAT, 16x1x3x3]
#   %onnx::Conv_524[FLOAT, 16]
#   %onnx::Conv_526[FLOAT, 16x16x1x1]
#   %onnx::Conv_527[FLOAT, 16]
#   %onnx::Conv_529[FLOAT, 64x16x1x1]
#   %onnx::Conv_530[FLOAT, 64]
#   %onnx::Conv_532[FLOAT, 64x1x3x3]
#   %onnx::Conv_533[FLOAT, 64]
#   %onnx::Conv_535[FLOAT, 24x64x1x1]
#   %onnx::Conv_536[FLOAT, 24]
#   %onnx::Conv_538[FLOAT, 72x24x1x1]
#   %onnx::Conv_539[FLOAT, 72]
#   %onnx::Conv_541[FLOAT, 72x1x3x3]
#   %onnx::Conv_542[FLOAT, 72]
#   %onnx::Conv_544[FLOAT, 24x72x1x1]
#   %onnx::Conv_545[FLOAT, 24]
#   %onnx::Conv_547[FLOAT, 72x24x1x1]
#   %onnx::Conv_548[FLOAT, 72]
#   %onnx::Conv_550[FLOAT, 72x1x5x5]
#   %onnx::Conv_551[FLOAT, 72]
#   %onnx::Conv_553[FLOAT, 40x72x1x1]
#   %onnx::Conv_554[FLOAT, 40]
#   %onnx::Conv_556[FLOAT, 120x40x1x1]
#   %onnx::Conv_557[FLOAT, 120]
#   %onnx::Conv_559[FLOAT, 120x1x5x5]
#   %onnx::Conv_560[FLOAT, 120]
#   %onnx::Conv_562[FLOAT, 40x120x1x1]
#   %onnx::Conv_563[FLOAT, 40]
#   %onnx::Conv_565[FLOAT, 120x40x1x1]
#   %onnx::Conv_566[FLOAT, 120]
#   %onnx::Conv_568[FLOAT, 120x1x5x5]
#   %onnx::Conv_569[FLOAT, 120]
#   %onnx::Conv_571[FLOAT, 40x120x1x1]
#   %onnx::Conv_572[FLOAT, 40]
#   %onnx::Conv_574[FLOAT, 240x40x1x1]
#   %onnx::Conv_575[FLOAT, 240]
#   %onnx::Conv_577[FLOAT, 240x1x3x3]
#   %onnx::Conv_578[FLOAT, 240]
#   %onnx::Conv_580[FLOAT, 80x240x1x1]
#   %onnx::Conv_581[FLOAT, 80]
#   %onnx::Conv_583[FLOAT, 200x80x1x1]
#   %onnx::Conv_584[FLOAT, 200]
#   %onnx::Conv_586[FLOAT, 200x1x3x3]
#   %onnx::Conv_587[FLOAT, 200]
#   %onnx::Conv_589[FLOAT, 80x200x1x1]
#   %onnx::Conv_590[FLOAT, 80]
#   %onnx::Conv_592[FLOAT, 184x80x1x1]
#   %onnx::Conv_593[FLOAT, 184]
#   %onnx::Conv_595[FLOAT, 184x1x3x3]
#   %onnx::Conv_596[FLOAT, 184]
#   %onnx::Conv_598[FLOAT, 80x184x1x1]
#   %onnx::Conv_599[FLOAT, 80]
#   %onnx::Conv_601[FLOAT, 184x80x1x1]
#   %onnx::Conv_602[FLOAT, 184]
#   %onnx::Conv_604[FLOAT, 184x1x3x3]
#   %onnx::Conv_605[FLOAT, 184]
#   %onnx::Conv_607[FLOAT, 80x184x1x1]
#   %onnx::Conv_608[FLOAT, 80]
#   %onnx::Conv_610[FLOAT, 480x80x1x1]
#   %onnx::Conv_611[FLOAT, 480]
#   %onnx::Conv_613[FLOAT, 480x1x3x3]
#   %onnx::Conv_614[FLOAT, 480]
#   %onnx::Conv_616[FLOAT, 112x480x1x1]
#   %onnx::Conv_617[FLOAT, 112]
#   %onnx::Conv_619[FLOAT, 672x112x1x1]
#   %onnx::Conv_620[FLOAT, 672]
#   %onnx::Conv_622[FLOAT, 672x1x3x3]
#   %onnx::Conv_623[FLOAT, 672]
#   %onnx::Conv_625[FLOAT, 112x672x1x1]
#   %onnx::Conv_626[FLOAT, 112]
#   %onnx::Conv_628[FLOAT, 672x112x1x1]
#   %onnx::Conv_629[FLOAT, 672]
#   %onnx::Conv_631[FLOAT, 672x1x5x5]
#   %onnx::Conv_632[FLOAT, 672]
#   %onnx::Conv_634[FLOAT, 160x672x1x1]
#   %onnx::Conv_635[FLOAT, 160]
#   %onnx::Conv_637[FLOAT, 960x160x1x1]
#   %onnx::Conv_638[FLOAT, 960]
#   %onnx::Conv_640[FLOAT, 960x1x5x5]
#   %onnx::Conv_641[FLOAT, 960]
#   %onnx::Conv_643[FLOAT, 160x960x1x1]
#   %onnx::Conv_644[FLOAT, 160]
#   %onnx::Conv_646[FLOAT, 960x160x1x1]
#   %onnx::Conv_647[FLOAT, 960]
#   %onnx::Conv_649[FLOAT, 960x1x5x5]
#   %onnx::Conv_650[FLOAT, 960]
#   %onnx::Conv_652[FLOAT, 160x960x1x1]
#   %onnx::Conv_653[FLOAT, 160]
#   %onnx::Conv_655[FLOAT, 960x160x1x1]
#   %onnx::Conv_656[FLOAT, 960]
# ) {
#   %/features/features.0/features.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%input, %onnx::Conv_520, %onnx::Conv_521)
#   %/features/features.0/features.0.2/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.0/features.0.0/Conv_output_0)
#   %/features/features.0/features.0.2/Mul_output_0 = Mul(%/features/features.0/features.0.0/Conv_output_0, %/features/features.0/features.0.2/HardSigmoid_output_0)
#   %/features/features.1/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 16, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.0/features.0.2/Mul_output_0, %onnx::Conv_523, %onnx::Conv_524)
#   %/features/features.1/block/block.0/block.0.2/Relu_output_0 = Relu(%/features/features.1/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.1/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.1/block/block.0/block.0.2/Relu_output_0, %onnx::Conv_526, %onnx::Conv_527)
#   %/features/features.1/Add_output_0 = Add(%/features/features.1/block/block.1/block.1.0/Conv_output_0, %/features/features.0/features.0.2/Mul_output_0)
#   %/features/features.2/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.1/Add_output_0, %onnx::Conv_529, %onnx::Conv_530)
#   %/features/features.2/block/block.0/block.0.2/Relu_output_0 = Relu(%/features/features.2/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.2/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 64, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%/features/features.2/block/block.0/block.0.2/Relu_output_0, %onnx::Conv_532, %onnx::Conv_533)
#   %/features/features.2/block/block.1/block.1.2/Relu_output_0 = Relu(%/features/features.2/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.2/block/block.2/block.2.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.2/block/block.1/block.1.2/Relu_output_0, %onnx::Conv_535, %onnx::Conv_536)
#   %/features/features.3/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.2/block/block.2/block.2.0/Conv_output_0, %onnx::Conv_538, %onnx::Conv_539)
#   %/features/features.3/block/block.0/block.0.2/Relu_output_0 = Relu(%/features/features.3/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.3/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 72, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.3/block/block.0/block.0.2/Relu_output_0, %onnx::Conv_541, %onnx::Conv_542)
#   %/features/features.3/block/block.1/block.1.2/Relu_output_0 = Relu(%/features/features.3/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.3/block/block.2/block.2.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.3/block/block.1/block.1.2/Relu_output_0, %onnx::Conv_544, %onnx::Conv_545)
#   %/features/features.3/Add_output_0 = Add(%/features/features.3/block/block.2/block.2.0/Conv_output_0, %/features/features.2/block/block.2/block.2.0/Conv_output_0)
#   %/features/features.4/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.3/Add_output_0, %onnx::Conv_547, %onnx::Conv_548)
#   %/features/features.4/block/block.0/block.0.2/Relu_output_0 = Relu(%/features/features.4/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.4/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 72, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [2, 2]](%/features/features.4/block/block.0/block.0.2/Relu_output_0, %onnx::Conv_550, %onnx::Conv_551)
#   %/features/features.4/block/block.1/block.1.2/Relu_output_0 = Relu(%/features/features.4/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.4/block/block.2/avgpool/GlobalAveragePool_output_0 = GlobalAveragePool(%/features/features.4/block/block.1/block.1.2/Relu_output_0)
#   %/features/features.4/block/block.2/fc1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.4/block/block.2/avgpool/GlobalAveragePool_output_0, %features.4.block.2.fc1.weight, %features.4.block.2.fc1.bias)
#   %/features/features.4/block/block.2/activation/Relu_output_0 = Relu(%/features/features.4/block/block.2/fc1/Conv_output_0)
#   %/features/features.4/block/block.2/fc2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.4/block/block.2/activation/Relu_output_0, %features.4.block.2.fc2.weight, %features.4.block.2.fc2.bias)
#   %/features/features.4/block/block.2/scale_activation/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.4/block/block.2/fc2/Conv_output_0)
#   %/features/features.4/block/block.2/Mul_output_0 = Mul(%/features/features.4/block/block.2/scale_activation/HardSigmoid_output_0, %/features/features.4/block/block.1/block.1.2/Relu_output_0)
#   %/features/features.4/block/block.3/block.3.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.4/block/block.2/Mul_output_0, %onnx::Conv_553, %onnx::Conv_554)
#   %/features/features.5/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.4/block/block.3/block.3.0/Conv_output_0, %onnx::Conv_556, %onnx::Conv_557)
#   %/features/features.5/block/block.0/block.0.2/Relu_output_0 = Relu(%/features/features.5/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.5/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 120, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [1, 1]](%/features/features.5/block/block.0/block.0.2/Relu_output_0, %onnx::Conv_559, %onnx::Conv_560)
#   %/features/features.5/block/block.1/block.1.2/Relu_output_0 = Relu(%/features/features.5/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.5/block/block.2/avgpool/GlobalAveragePool_output_0 = GlobalAveragePool(%/features/features.5/block/block.1/block.1.2/Relu_output_0)
#   %/features/features.5/block/block.2/fc1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.5/block/block.2/avgpool/GlobalAveragePool_output_0, %features.5.block.2.fc1.weight, %features.5.block.2.fc1.bias)
#   %/features/features.5/block/block.2/activation/Relu_output_0 = Relu(%/features/features.5/block/block.2/fc1/Conv_output_0)
#   %/features/features.5/block/block.2/fc2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.5/block/block.2/activation/Relu_output_0, %features.5.block.2.fc2.weight, %features.5.block.2.fc2.bias)
#   %/features/features.5/block/block.2/scale_activation/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.5/block/block.2/fc2/Conv_output_0)
#   %/features/features.5/block/block.2/Mul_output_0 = Mul(%/features/features.5/block/block.2/scale_activation/HardSigmoid_output_0, %/features/features.5/block/block.1/block.1.2/Relu_output_0)
#   %/features/features.5/block/block.3/block.3.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.5/block/block.2/Mul_output_0, %onnx::Conv_562, %onnx::Conv_563)
#   %/features/features.5/Add_output_0 = Add(%/features/features.5/block/block.3/block.3.0/Conv_output_0, %/features/features.4/block/block.3/block.3.0/Conv_output_0)
#   %/features/features.6/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.5/Add_output_0, %onnx::Conv_565, %onnx::Conv_566)
#   %/features/features.6/block/block.0/block.0.2/Relu_output_0 = Relu(%/features/features.6/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.6/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 120, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [1, 1]](%/features/features.6/block/block.0/block.0.2/Relu_output_0, %onnx::Conv_568, %onnx::Conv_569)
#   %/features/features.6/block/block.1/block.1.2/Relu_output_0 = Relu(%/features/features.6/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.6/block/block.2/avgpool/GlobalAveragePool_output_0 = GlobalAveragePool(%/features/features.6/block/block.1/block.1.2/Relu_output_0)
#   %/features/features.6/block/block.2/fc1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.6/block/block.2/avgpool/GlobalAveragePool_output_0, %features.6.block.2.fc1.weight, %features.6.block.2.fc1.bias)
#   %/features/features.6/block/block.2/activation/Relu_output_0 = Relu(%/features/features.6/block/block.2/fc1/Conv_output_0)
#   %/features/features.6/block/block.2/fc2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.6/block/block.2/activation/Relu_output_0, %features.6.block.2.fc2.weight, %features.6.block.2.fc2.bias)
#   %/features/features.6/block/block.2/scale_activation/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.6/block/block.2/fc2/Conv_output_0)
#   %/features/features.6/block/block.2/Mul_output_0 = Mul(%/features/features.6/block/block.2/scale_activation/HardSigmoid_output_0, %/features/features.6/block/block.1/block.1.2/Relu_output_0)
#   %/features/features.6/block/block.3/block.3.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.6/block/block.2/Mul_output_0, %onnx::Conv_571, %onnx::Conv_572)
#   %/features/features.6/Add_output_0 = Add(%/features/features.6/block/block.3/block.3.0/Conv_output_0, %/features/features.5/Add_output_0)
#   %/features/features.7/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.6/Add_output_0, %onnx::Conv_574, %onnx::Conv_575)
#   %/features/features.7/block/block.0/block.0.2/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.7/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.7/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.7/block/block.0/block.0.0/Conv_output_0, %/features/features.7/block/block.0/block.0.2/HardSigmoid_output_0)
#   %/features/features.7/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 240, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%/features/features.7/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_577, %onnx::Conv_578)
#   %/features/features.7/block/block.1/block.1.2/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.7/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.7/block/block.1/block.1.2/Mul_output_0 = Mul(%/features/features.7/block/block.1/block.1.0/Conv_output_0, %/features/features.7/block/block.1/block.1.2/HardSigmoid_output_0)
#   %/features/features.7/block/block.2/block.2.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/block/block.1/block.1.2/Mul_output_0, %onnx::Conv_580, %onnx::Conv_581)
#   %/features/features.8/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/block/block.2/block.2.0/Conv_output_0, %onnx::Conv_583, %onnx::Conv_584)
#   %/features/features.8/block/block.0/block.0.2/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.8/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.8/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.8/block/block.0/block.0.0/Conv_output_0, %/features/features.8/block/block.0/block.0.2/HardSigmoid_output_0)
#   %/features/features.8/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 200, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.8/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_586, %onnx::Conv_587)
#   %/features/features.8/block/block.1/block.1.2/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.8/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.8/block/block.1/block.1.2/Mul_output_0 = Mul(%/features/features.8/block/block.1/block.1.0/Conv_output_0, %/features/features.8/block/block.1/block.1.2/HardSigmoid_output_0)
#   %/features/features.8/block/block.2/block.2.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.8/block/block.1/block.1.2/Mul_output_0, %onnx::Conv_589, %onnx::Conv_590)
#   %/features/features.8/Add_output_0 = Add(%/features/features.8/block/block.2/block.2.0/Conv_output_0, %/features/features.7/block/block.2/block.2.0/Conv_output_0)
#   %/features/features.9/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.8/Add_output_0, %onnx::Conv_592, %onnx::Conv_593)
#   %/features/features.9/block/block.0/block.0.2/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.9/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.9/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.9/block/block.0/block.0.0/Conv_output_0, %/features/features.9/block/block.0/block.0.2/HardSigmoid_output_0)
#   %/features/features.9/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 184, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.9/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_595, %onnx::Conv_596)
#   %/features/features.9/block/block.1/block.1.2/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.9/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.9/block/block.1/block.1.2/Mul_output_0 = Mul(%/features/features.9/block/block.1/block.1.0/Conv_output_0, %/features/features.9/block/block.1/block.1.2/HardSigmoid_output_0)
#   %/features/features.9/block/block.2/block.2.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.9/block/block.1/block.1.2/Mul_output_0, %onnx::Conv_598, %onnx::Conv_599)
#   %/features/features.9/Add_output_0 = Add(%/features/features.9/block/block.2/block.2.0/Conv_output_0, %/features/features.8/Add_output_0)
#   %/features/features.10/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.9/Add_output_0, %onnx::Conv_601, %onnx::Conv_602)
#   %/features/features.10/block/block.0/block.0.2/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.10/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.10/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.10/block/block.0/block.0.0/Conv_output_0, %/features/features.10/block/block.0/block.0.2/HardSigmoid_output_0)
#   %/features/features.10/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 184, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.10/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_604, %onnx::Conv_605)
#   %/features/features.10/block/block.1/block.1.2/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.10/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.10/block/block.1/block.1.2/Mul_output_0 = Mul(%/features/features.10/block/block.1/block.1.0/Conv_output_0, %/features/features.10/block/block.1/block.1.2/HardSigmoid_output_0)
#   %/features/features.10/block/block.2/block.2.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.10/block/block.1/block.1.2/Mul_output_0, %onnx::Conv_607, %onnx::Conv_608)
#   %/features/features.10/Add_output_0 = Add(%/features/features.10/block/block.2/block.2.0/Conv_output_0, %/features/features.9/Add_output_0)
#   %/features/features.11/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.10/Add_output_0, %onnx::Conv_610, %onnx::Conv_611)
#   %/features/features.11/block/block.0/block.0.2/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.11/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.11/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.11/block/block.0/block.0.0/Conv_output_0, %/features/features.11/block/block.0/block.0.2/HardSigmoid_output_0)
#   %/features/features.11/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 480, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.11/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_613, %onnx::Conv_614)
#   %/features/features.11/block/block.1/block.1.2/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.11/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.11/block/block.1/block.1.2/Mul_output_0 = Mul(%/features/features.11/block/block.1/block.1.0/Conv_output_0, %/features/features.11/block/block.1/block.1.2/HardSigmoid_output_0)
#   %/features/features.11/block/block.2/avgpool/GlobalAveragePool_output_0 = GlobalAveragePool(%/features/features.11/block/block.1/block.1.2/Mul_output_0)
#   %/features/features.11/block/block.2/fc1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.11/block/block.2/avgpool/GlobalAveragePool_output_0, %features.11.block.2.fc1.weight, %features.11.block.2.fc1.bias)
#   %/features/features.11/block/block.2/activation/Relu_output_0 = Relu(%/features/features.11/block/block.2/fc1/Conv_output_0)
#   %/features/features.11/block/block.2/fc2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.11/block/block.2/activation/Relu_output_0, %features.11.block.2.fc2.weight, %features.11.block.2.fc2.bias)
#   %/features/features.11/block/block.2/scale_activation/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.11/block/block.2/fc2/Conv_output_0)
#   %/features/features.11/block/block.2/Mul_output_0 = Mul(%/features/features.11/block/block.2/scale_activation/HardSigmoid_output_0, %/features/features.11/block/block.1/block.1.2/Mul_output_0)
#   %/features/features.11/block/block.3/block.3.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.11/block/block.2/Mul_output_0, %onnx::Conv_616, %onnx::Conv_617)
#   %/features/features.12/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.11/block/block.3/block.3.0/Conv_output_0, %onnx::Conv_619, %onnx::Conv_620)
#   %/features/features.12/block/block.0/block.0.2/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.12/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.12/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.12/block/block.0/block.0.0/Conv_output_0, %/features/features.12/block/block.0/block.0.2/HardSigmoid_output_0)
#   %/features/features.12/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 672, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.12/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_622, %onnx::Conv_623)
#   %/features/features.12/block/block.1/block.1.2/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.12/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.12/block/block.1/block.1.2/Mul_output_0 = Mul(%/features/features.12/block/block.1/block.1.0/Conv_output_0, %/features/features.12/block/block.1/block.1.2/HardSigmoid_output_0)
#   %/features/features.12/block/block.2/avgpool/GlobalAveragePool_output_0 = GlobalAveragePool(%/features/features.12/block/block.1/block.1.2/Mul_output_0)
#   %/features/features.12/block/block.2/fc1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.12/block/block.2/avgpool/GlobalAveragePool_output_0, %features.12.block.2.fc1.weight, %features.12.block.2.fc1.bias)
#   %/features/features.12/block/block.2/activation/Relu_output_0 = Relu(%/features/features.12/block/block.2/fc1/Conv_output_0)
#   %/features/features.12/block/block.2/fc2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.12/block/block.2/activation/Relu_output_0, %features.12.block.2.fc2.weight, %features.12.block.2.fc2.bias)
#   %/features/features.12/block/block.2/scale_activation/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.12/block/block.2/fc2/Conv_output_0)
#   %/features/features.12/block/block.2/Mul_output_0 = Mul(%/features/features.12/block/block.2/scale_activation/HardSigmoid_output_0, %/features/features.12/block/block.1/block.1.2/Mul_output_0)
#   %/features/features.12/block/block.3/block.3.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.12/block/block.2/Mul_output_0, %onnx::Conv_625, %onnx::Conv_626)
#   %/features/features.12/Add_output_0 = Add(%/features/features.12/block/block.3/block.3.0/Conv_output_0, %/features/features.11/block/block.3/block.3.0/Conv_output_0)
#   %/features/features.13/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.12/Add_output_0, %onnx::Conv_628, %onnx::Conv_629)
#   %/features/features.13/block/block.0/block.0.2/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.13/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.13/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.13/block/block.0/block.0.0/Conv_output_0, %/features/features.13/block/block.0/block.0.2/HardSigmoid_output_0)
#   %/features/features.13/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 672, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [2, 2]](%/features/features.13/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_631, %onnx::Conv_632)
#   %/features/features.13/block/block.1/block.1.2/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.13/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.13/block/block.1/block.1.2/Mul_output_0 = Mul(%/features/features.13/block/block.1/block.1.0/Conv_output_0, %/features/features.13/block/block.1/block.1.2/HardSigmoid_output_0)
#   %/features/features.13/block/block.2/avgpool/GlobalAveragePool_output_0 = GlobalAveragePool(%/features/features.13/block/block.1/block.1.2/Mul_output_0)
#   %/features/features.13/block/block.2/fc1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.13/block/block.2/avgpool/GlobalAveragePool_output_0, %features.13.block.2.fc1.weight, %features.13.block.2.fc1.bias)
#   %/features/features.13/block/block.2/activation/Relu_output_0 = Relu(%/features/features.13/block/block.2/fc1/Conv_output_0)
#   %/features/features.13/block/block.2/fc2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.13/block/block.2/activation/Relu_output_0, %features.13.block.2.fc2.weight, %features.13.block.2.fc2.bias)
#   %/features/features.13/block/block.2/scale_activation/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.13/block/block.2/fc2/Conv_output_0)
#   %/features/features.13/block/block.2/Mul_output_0 = Mul(%/features/features.13/block/block.2/scale_activation/HardSigmoid_output_0, %/features/features.13/block/block.1/block.1.2/Mul_output_0)
#   %/features/features.13/block/block.3/block.3.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.13/block/block.2/Mul_output_0, %onnx::Conv_634, %onnx::Conv_635)
#   %/features/features.14/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.13/block/block.3/block.3.0/Conv_output_0, %onnx::Conv_637, %onnx::Conv_638)
#   %/features/features.14/block/block.0/block.0.2/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.14/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.14/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.14/block/block.0/block.0.0/Conv_output_0, %/features/features.14/block/block.0/block.0.2/HardSigmoid_output_0)
#   %/features/features.14/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 960, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [1, 1]](%/features/features.14/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_640, %onnx::Conv_641)
#   %/features/features.14/block/block.1/block.1.2/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.14/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.14/block/block.1/block.1.2/Mul_output_0 = Mul(%/features/features.14/block/block.1/block.1.0/Conv_output_0, %/features/features.14/block/block.1/block.1.2/HardSigmoid_output_0)
#   %/features/features.14/block/block.2/avgpool/GlobalAveragePool_output_0 = GlobalAveragePool(%/features/features.14/block/block.1/block.1.2/Mul_output_0)
#   %/features/features.14/block/block.2/fc1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.14/block/block.2/avgpool/GlobalAveragePool_output_0, %features.14.block.2.fc1.weight, %features.14.block.2.fc1.bias)
#   %/features/features.14/block/block.2/activation/Relu_output_0 = Relu(%/features/features.14/block/block.2/fc1/Conv_output_0)
#   %/features/features.14/block/block.2/fc2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.14/block/block.2/activation/Relu_output_0, %features.14.block.2.fc2.weight, %features.14.block.2.fc2.bias)
#   %/features/features.14/block/block.2/scale_activation/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.14/block/block.2/fc2/Conv_output_0)
#   %/features/features.14/block/block.2/Mul_output_0 = Mul(%/features/features.14/block/block.2/scale_activation/HardSigmoid_output_0, %/features/features.14/block/block.1/block.1.2/Mul_output_0)
#   %/features/features.14/block/block.3/block.3.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.14/block/block.2/Mul_output_0, %onnx::Conv_643, %onnx::Conv_644)
#   %/features/features.14/Add_output_0 = Add(%/features/features.14/block/block.3/block.3.0/Conv_output_0, %/features/features.13/block/block.3/block.3.0/Conv_output_0)
#   %/features/features.15/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.14/Add_output_0, %onnx::Conv_646, %onnx::Conv_647)
#   %/features/features.15/block/block.0/block.0.2/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.15/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.15/block/block.0/block.0.2/Mul_output_0 = Mul(%/features/features.15/block/block.0/block.0.0/Conv_output_0, %/features/features.15/block/block.0/block.0.2/HardSigmoid_output_0)
#   %/features/features.15/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 960, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [1, 1]](%/features/features.15/block/block.0/block.0.2/Mul_output_0, %onnx::Conv_649, %onnx::Conv_650)
#   %/features/features.15/block/block.1/block.1.2/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.15/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.15/block/block.1/block.1.2/Mul_output_0 = Mul(%/features/features.15/block/block.1/block.1.0/Conv_output_0, %/features/features.15/block/block.1/block.1.2/HardSigmoid_output_0)
#   %/features/features.15/block/block.2/avgpool/GlobalAveragePool_output_0 = GlobalAveragePool(%/features/features.15/block/block.1/block.1.2/Mul_output_0)
#   %/features/features.15/block/block.2/fc1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.15/block/block.2/avgpool/GlobalAveragePool_output_0, %features.15.block.2.fc1.weight, %features.15.block.2.fc1.bias)
#   %/features/features.15/block/block.2/activation/Relu_output_0 = Relu(%/features/features.15/block/block.2/fc1/Conv_output_0)
#   %/features/features.15/block/block.2/fc2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.15/block/block.2/activation/Relu_output_0, %features.15.block.2.fc2.weight, %features.15.block.2.fc2.bias)
#   %/features/features.15/block/block.2/scale_activation/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.15/block/block.2/fc2/Conv_output_0)
#   %/features/features.15/block/block.2/Mul_output_0 = Mul(%/features/features.15/block/block.2/scale_activation/HardSigmoid_output_0, %/features/features.15/block/block.1/block.1.2/Mul_output_0)
#   %/features/features.15/block/block.3/block.3.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.15/block/block.2/Mul_output_0, %onnx::Conv_652, %onnx::Conv_653)
#   %/features/features.15/Add_output_0 = Add(%/features/features.15/block/block.3/block.3.0/Conv_output_0, %/features/features.14/Add_output_0)
#   %/features/features.16/features.16.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.15/Add_output_0, %onnx::Conv_655, %onnx::Conv_656)
#   %/features/features.16/features.16.2/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.16/features.16.0/Conv_output_0)
#   %/features/features.16/features.16.2/Mul_output_0 = Mul(%/features/features.16/features.16.0/Conv_output_0, %/features/features.16/features.16.2/HardSigmoid_output_0)
#   %/avgpool/GlobalAveragePool_output_0 = GlobalAveragePool(%/features/features.16/features.16.2/Mul_output_0)
#   %/Flatten_output_0 = Flatten[axis = 1](%/avgpool/GlobalAveragePool_output_0)
#   %/classifier/classifier.0/Gemm_output_0 = Gemm[alpha = 1, beta = 1, transB = 1](%/Flatten_output_0, %classifier.0.weight, %classifier.0.bias)
#   %/classifier/classifier.1/Relu_output_0 = Relu(%/classifier/classifier.0/Gemm_output_0)
#   %output = Gemm[alpha = 1, beta = 1, transB = 1](%/classifier/classifier.1/Relu_output_0, %classifier.2.weight, %classifier.2.bias)
#   return %output
# }

# %% [markdown]
# ## 使用Netron可视化模型结构
#
# Netron：https://netron.app
#
# 视频教程：https://www.bilibili.com/video/BV1TV4y1P7AP
